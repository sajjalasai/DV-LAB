# %%
import pandas as pd
import numpy as np

# %%
dd=pd.read_csv("Airline_Bookings.csv")

# %%
dd.head(3)
# Out:
#   Booking ID    Source  Destination Flight ID     Class  Amount Booking Date  \
# 0       B001  New York  Los Angeles     F1001   Economy     300   2025-01-01
# 1       B002   Chicago        Miami     F1002  Business     550   2025-01-02
# 2       B003    Dallas       Denver     F1003   Economy     200   2025-01-03
#
#   Travelled Date
# 0     2025-01-10
# 1     2025-01-11
# 2     2025-01-15

# %%
dd.tail(3)
# Out:
#   Booking ID     Source Destination Flight ID     Class  Amount Booking Date  \
# 7       B008   New York     Chicago     F1008     First     700   2025-01-08
# 8       B009      Miami      Boston     F1009   Economy     250   2025-01-09
# 9       B010  San Diego     Seattle     F1010  Business     500   2025-01-10
#
#   Travelled Date
# 7     2025-01-17
# 8     2025-01-19
# 9     2025-01-25

# %%
dd.dtypes
# Out:
# Booking ID        object
# Source            object
# Destination       object
# Flight ID         object
# Class             object
# Amount             int64
# Booking Date      object
# Travelled Date    object
# dtype: object

# %%
print(dd)
# Out:
#   Booking ID     Source    Destination Flight ID     Class  Amount  \
# 0       B001   New York    Los Angeles     F1001   Economy     300
# 1       B002    Chicago          Miami     F1002  Business     550
# 2       B003     Dallas         Denver     F1003   Economy     200
# 3       B004    Seattle  San Francisco     F1004   Economy     150
# 4       B005     Boston        Atlanta     F1005     First     800
# 5       B006    Houston        Orlando     F1006  Business     450
# 6       B007    Phoenix      Las Vegas     F1007   Economy     100
# 7       B008   New York        Chicago     F1008     First     700
# 8       B009      Miami         Boston     F1009   Economy     250
# 9       B010  San Diego        Seattle     F1010  Business     500
#
#   Booking Date Travelled Date
# 0   2025-01-01     2025-01-10
# 1   2025-01-02     2025-01-11
# 2   2025-01-03     2025-01-15
# 3   2025-01-04     2025-01-14
# 4   2025-01-05     2025-01-20
# 5   2025-01-06     2025-01-18
# ...

# %%
print(dd.isnull())
# Out:
#    Booking ID  Source  Destination  Flight ID  Class  Amount  Booking Date  \
# 0       False   False        False      False  False   False         False
# 1       False   False        False      False  False   False         False
# 2       False   False        False      False  False   False         False
# 3       False   False        False      False  False   False         False
# 4       False   False        False      False  False   False         False
# 5       False   False        False      False  False   False         False
# 6       False   False        False      False  False   False         False
# 7       False   False        False      False  False   False         False
# 8       False   False        False      False  False   False         False
# 9       False   False        False      False  False   False         False
#
#    Travelled Date
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# ...

# %%
dd.shape
# Out:
# (10, 8)

# %%
dd.count()
# Out:
# Booking ID        10
# Source            10
# Destination       10
# Flight ID         10
# Class             10
# Amount            10
# Booking Date      10
# Travelled Date    10
# dtype: int64

# %%
df = dd.drop(['Travelled Date','Booking Date'], axis=1)
df.head(5)
# Out:
#   Booking ID    Source    Destination Flight ID     Class  Amount
# 0       B001  New York    Los Angeles     F1001   Economy     300
# 1       B002   Chicago          Miami     F1002  Business     550
# 2       B003    Dallas         Denver     F1003   Economy     200
# 3       B004   Seattle  San Francisco     F1004   Economy     150
# 4       B005    Boston        Atlanta     F1005     First     800

# %%
df = df.rename(columns={"Booking Id": "B_ID", "Flight ID": "F_Id", })
df.head(5)
# Out:
#   Booking ID    Source    Destination   F_Id     Class  Amount
# 0       B001  New York    Los Angeles  F1001   Economy     300
# 1       B002   Chicago          Miami  F1002  Business     550
# 2       B003    Dallas         Denver  F1003   Economy     200
# 3       B004   Seattle  San Francisco  F1004   Economy     150
# 4       B005    Boston        Atlanta  F1005     First     800

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
s=df.duplicated()
s.shape
# Out:
# (10,)

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#   Booking ID    Source    Destination   F_Id     Class  Amount
# 0       B001  New York    Los Angeles  F1001   Economy     300
# 1       B002   Chicago          Miami  F1002  Business     550
# 2       B003    Dallas         Denver  F1003   Economy     200
# 3       B004   Seattle  San Francisco  F1004   Economy     150
# 4       B005    Boston        Atlanta  F1005     First     800

# %%
df.count()
# Out:
# Booking ID     10
# Source         10
# Destination    10
# F_Id           10
# Class          10
# Amount         10
# dtype: int64

# %%
print(df.isnull().sum())
df = df.dropna()
df.count()
# Out:
# Booking ID     0
# Source         0
# Destination    0
# F_Id           0
# Class          0
# Amount         0
# dtype: int64
# Booking ID     10
# Source         10
# Destination    10
# F_Id           10
# Class          10
# Amount         10
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Booking ID     0
# Source         0
# Destination    0
# F_Id           0
# Class          0
# Amount         0
# dtype: int64
